# %%
import urllib, json
import os

REMOTE_JSON = 'https://raw.githubusercontent.com/plotly/plotly.js/master/test/image/mocks/sankey_energy.json'
LOCAL_JSON  = 'data/sankey_energy.json'
BUG_INFO    = 'data/bug_20200806.csv'
REQ_INFO    = 'data/req_20200806.csv'
REQ_HIS     = 'data/req_history.csv'

def load_sankey_color():
    if not os.path.exists(LOCAL_JSON):
        with urllib.request.urlopen(REMOTE_JSON) as sankey, open(LOCAL_JSON, 'wb') as local:
            local.write(sankey.read())

    with open(LOCAL_JSON) as fp:
        return json.load(fp)

# %%
bugs = pd.read_csv(BUG_INFO)
# bugs[bugs['BUG']]
# bugs[bugs['BUG'] == np.nan] = False
# bugs[bugs.fillna(False)['BUG']]
# bug_list[bug_list['需求池ID'].isnull()]
# tmp_bug = bug_list[~bug_list['维修人员'].isnull()][['维修人员','BUG等级']]

bugs[bugs.fillna({'BUG':False})['BUG']]

# %%
data = load_sankey_color()
opacity = 0.4
# colors = data['data'][0]['node']['color'] 
node_colors = ['rgba(255,0,255, 0.8)' if color == "magenta" else color for color in data['data'][0]['node']['color']]
link_colors = [data['data'][0]['node']['color'][src].replace("0.8", str(opacity))
                                    for src in data['data'][0]['link']['source']]

link_colors = link_colors * 2

# %%
pd.set_option('display.max_rows', None)

# %%
req_id = pd.read_csv(REQ_HIS, encoding='utf8', header=1)
tm = req_id[req_id['需求池简要']=='5G快签创建模板需求']
tm
# Out:
#    需求池ID   所属主项目       需求池简要  \
# 4    837  simapp  5G快签创建模板需求
#
#                                      需求池confluence地址 需求池状态 需求池类型  创建人  更新人  \
# 4  http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...   已排期    需求  杨少东  杨少东
#
#                   创建时间                 修改时间
# 4  2020-07-29 15:33:01  2020-08-10 11:09:00

# %%
import pandas as pd
import numpy  as np
import urllib, json
import reprlib 
import plotly.graph_objects as go


# 数据映射方式将名字缩写变更为名字全称
full_name = {'创彬':'王创彬','王创彬':'王创彬',
            '嘉佳':'吴嘉佳','吴嘉佳':'吴嘉佳',
            '计成':'叶计成','叶计成':'叶计成',
            '连子':'刘连子','刘连子':'刘连子',
            '作伍':'谭作伍','谭作伍':'谭作伍',
            '梓杰':'林梓杰','林梓杰':'林梓杰',
            '青云':'徐青云','徐青云':'林梓杰',
            '宇鹏':'黄宇鹏','黄宇鹏':'林梓杰',
            '广琪':'余广琪','余广琪':'林梓杰',
            '晓泉':'龙晓泉','龙晓泉':'林梓杰'
            }

# url = 'https://raw.githubusercontent.com/plotly/plotly.js/master/test/image/mocks/sankey_energy.json'
# response = urllib.request.urlopen(url)
# data = json.loads(response.read())


label_colors = ['rgba(31, 119, 180, 0.8)',
 'rgba(255, 127, 14, 0.8)',
 'rgba(148, 103, 189, 0.8)',
 'rgba(140, 86, 75, 0.8)',
 'rgba(227, 119, 194, 0.8)',
 'rgba(127, 127, 127, 0.8)',
 'rgba(188, 189, 34, 0.8)',
 'rgba(23, 190, 207, 0.8)',
 'rgba(31, 119, 180, 0.8)',
 'rgba(255, 127, 14, 0.8)',
 'rgba(148, 103, 189, 0.8)',
 'rgba(140, 86, 75, 0.8)',
 'rgba(227, 119, 194, 0.8)',
 'rgba(127, 127, 127, 0.8)',
 'rgba(188, 189, 34, 0.8)',
 'rgba(23, 190, 207, 0.8)',
 'rgba(31, 119, 180, 0.8)',
 'rgba(255, 127, 14, 0.8)',
 'rgba(44, 160, 44, 0.8)',
 'rgba(140, 86, 75, 0.8)',
 'rgba(227, 119, 194, 0.8)',
 'rgba(127, 127, 127, 0.8)',
 'rgba(188, 189, 34, 0.8)'] 

# label_colors = ['rgba(31, 119, 180, 0.8)',
#  'rgba(255, 127, 14, 0.8)',
#  'rgba(214, 39, 40, 0.8)',
#  'rgba(44, 160, 44, 0.8)',
#  'rgba(148, 103, 189, 0.8)',
#  'rgba(140, 86, 75, 0.8)',
#  'rgba(227, 119, 194, 0.8)',
#  'rgba(127, 127, 127, 0.8)',
#  'rgba(188, 189, 34, 0.8)',
#  'rgba(23, 190, 207, 0.8)',
#  'rgba(31, 119, 180, 0.8)',
#  'rgba(255, 127, 14, 0.8)',
#  'rgba(214, 39, 40, 0.8)',
#  'rgba(44, 160, 44, 0.8)',
#  'rgba(148, 103, 189, 0.8)',
#  'rgba(140, 86, 75, 0.8)',
#  'rgba(227, 119, 194, 0.8)',
#  'rgba(127, 127, 127, 0.8)',
#  'rgba(188, 189, 34, 0.8)',
#  'rgba(23, 190, 207, 0.8)',
#  'rgba(31, 119, 180, 0.8)',
#  'rgba(255, 127, 14, 0.8)',
#  'rgba(44, 160, 44, 0.8)',
#  'rgba(140, 86, 75, 0.8)',
#  'rgba(214, 39, 40, 0.8)',
#  'rgba(148, 103, 189, 0.8)',
#  'rgba(227, 119, 194, 0.8)',
#  'rgba(127, 127, 127, 0.8)',
#  'rgba(188, 189, 34, 0.8)'] 

bug_level_map = {'1级':'【BUG等级】致命','2级':'【BUG等级】严重','3级':'【BUG等级】一般','4级':'【BUG等级】微小','5级':'【BUG等级】提示'}

pd.set_option('display.max_rows', None)

# 
# 流水线任务分配信息
# 
# works=pd.read_html("../missions", encoding='utf8')
# works[1].drop('Unnamed: 0', axis=1).set_index(['需求ID'])
# dd=works[1].drop('Unnamed: 0',axis=1)

works = pd.read_csv(REQ_INFO, encoding='uft8',header=1).set_index(['需求ID'])
# 按需求ID聚合
missions=works.sort_values(by='需求ID')[['需求ID','需求名称','开发人员']]
missions['NUM'] = 1

label = missions[['需求ID','开发人员','NUM','需求名称']]
grouped = label['NUM'].groupby([label['需求ID'],label['开发人员']])
statics = dict(grouped.size())

data = [(key1,key2, statics[(key1,key2)]) for (key1,key2) in statics.keys() ]


# 导入超级号历史需求池ID

req_id = pd.read_csv(REQ_HIS, encoding='utf8', header=1)
tm = req_id[['需求ID','需求名称']]
req_map = {}
for i in tm.index:
    req_map[tm.iloc[i,0]] = tm.iloc[i,1].split("\"")[0] + '...'

    
#         
# BUG 列表信息
# 

bug_list = pd.read_csv('../超级号APP问题收集列表.csv')
bug_list[bug_list['需求池ID'].isnull()]
tmp_bug = bug_list[~bug_list['维修人员'].isnull()][['维修人员','BUG等级']]



stat_bug = dict(tmp_bug['BUG等级'].groupby([tmp_bug['维修人员'],tmp_bug['BUG等级']]).size())
data_bug = [(i,j,stat_bug[(i,j)]) for (i,j) in stat_bug.keys()]        

lable = []
x = []
y = list(np.arange(24)/100)

position = (0,0.5,0.9)

for (key1, key2) in statics.keys():
    if key1 not in lable:
        lable.append(key1)
        x.append(position[0])
    if key2 not in lable:
        lable.append(key2)
        x.append(position[1])

for (_,key2) in stat_bug:
    if key2 not in lable:
        lable.append(bug_level_map[key2])
        x.append(position[2])

# lable = tuple(lable)
# pilot    
# 映射对应关系列表
# 

sources = []
targets = []
values  = []

for (i,j,k) in data:
    sources.append(lable.index(i))
    targets.append(lable.index(j))
    values.append(k)

for (i,j,k) in data_bug:
    sources.append(lable.index(i))
    idx = bug_level_map[j]
    targets.append(lable.index(idx))
#     targets.append(lable.index(j))
    values.append(k)


# t = len(sources)
for i in lable:
    if type(i) == int:
        lable[lable.index(i)] = req_map[i]

color = link_colors[0:41] 
# colors[0:41]

fig = go.Figure(data=[go.Sankey(
    valueformat = "",
    arrangement = "snap",
    valuesuffix = "【开发任务数】",
    node = dict(
      pad = 15,
      thickness = 15,    
      line = dict(color = 'gray', width = 0.5),
      label =  lable,
      x=x,
      y=y,
      color =  colors
    ),
    link = dict(
      source =  sources,
      target =  targets,
      value =  values,
      color = link_colors
#       label =  data['data'][0]['link']['label']
  ))])

fig.update_layout(
    hovermode = 'x',
    title="超级号-研发质量分析<br>版本: 20200723版本【APP 1.0.5】<br>BUG等级分类（1）致命：（2）严重：（3）一般：微小：（5）提示：",
    font=dict(size =10, color = 'white'),
    plot_bgcolor='black',
    paper_bgcolor='black'
)

fig.show()
fig.write_html('/Users/dengjiaying/Project/gitee/Statics/SIMAPP/SIM20200723版本.html')

# %%
data = [(key1,key2, statics[(key1,key2)]) for (key1,key2) in statics.keys() ]
data
# Out:
# [(742, '余广琪', 2),
#  (742, '徐青云', 3),
#  (742, '莫南', 2),
#  (742, '龙晓泉', 2),
#  (765, '莫南', 2),
#  (799, '刘连子', 1),
#  (799, '林梓杰', 1),
#  (799, '莫南', 2),
#  (828, '莫南', 2),
#  (837, '余广琪', 2),
#  (837, '徐青云', 1),
#  (838, '余广琪', 2),
#  (838, '徐青云', 1),
#  (838, '黄宇鹏', 1),
#  (839, '余广琪', 2),
#  (839, '刘连子', 10),
#  (839, '叶计成', 5),
#  (839, '吴嘉佳', 16),
#  (839, '林梓杰', 7),
#  (839, '王创彬', 6),
#  (839, '莫南', 1),
#  (839, '谭作伍', 6),
#  (842, '刘连子', 1),
#  (842, '叶计成', 1),
#  (842, '吴嘉佳', 1),
#  (842, '林梓杰', 1),
#  (842, '王创彬', 3),
#  (842, '谭作伍', 1),
#  (843, '叶计成', 1),
#  (843, '吴嘉佳', 1),
#  (843, '王创彬', 2),
#  (844, '莫南', 2),
#  (845, '莫南', 2),
#  (845, '谭作伍', 1),
#  (848, '龙晓泉', 1),
#  (861, '莫南', 1)]

# %%
tm = missions[['需求ID','需求名称']]
req_map = {}
for i in tm.index:
    req_map[tm.iloc[i,0]] = tm.iloc[i,1].split("\"")[0] + '...'

req_map
# Out:
# {845: '接入超级SIM写卡组件...',
#  844: '后台优化需求16...',
#  843: '性能优化需求（41-44）...',
#  839: '3、功能优化需求（104-166）...',
#  842: 'UI优化需求 （43~70）...',
#  848: '需求点22:号卡体检检测接口优化...',
#  861: 'APP头像上传严格校验上传后缀...',
#  838: '超级号PC和移动端官网开发...',
#  837: '5G快签创建模板需求...',
#  828: '超级号管理后台渗透测试风险...',
#  742: '后台优化需求...',
#  765: '20200701超级号APP渗透测试风险...',
#  799: '功能优化需求...'}

# %%
import reprlib
[reprlib.repr(value) for req_itr,value in req_map.items()]
# Out:
# ["'接入超级SIM写卡组件...'",
#  "'后台优化需求16...'",
#  "'性能优化需求（41-44）...'",
#  "'3、功能优化需求（104-166）...'",
#  "'UI优化需求 （43~70）...'",
#  "'需求点22:号卡体检检测接口优化...'",
#  "'APP头像上传严格校验上传后缀...'",
#  "'超级号PC和移动端官网开发...'",
#  "'5G快签创建模板需求...'",
#  "'超级号管理后台渗透测试风险...'",
#  "'后台优化需求...'",
#  "'20200701超级号APP渗透测试风险...'",
#  "'功能优化需求...'"]

# %%
req_map.items()
# Out:
# dict_items([(845, '接入超级SIM写卡组件...'), (844, '后台优化需求16...'), (843, '性能优化需求（41-44）...'), (839, '3、功能优化需求（104-166）...'), (842, 'UI优化需求 （43~70）...'), (848, '需求点22:号卡体检检测接口优化...'), (861, 'APP头像上传严格校验上传后缀...'), (838, '超级号PC和移动端官网开发...'), (837, '5G快签创建模板需求...'), (828, '超级号管理后台渗透测试风险...'), (742, '后台优化需求...'), (765, '20200701超级号APP渗透测试风险...'), (799, '功能优化需求...')])

# %%
import pandas as pd
import numpy  as np
import urllib, json
import plotly.graph_objects as go

works=pd.read_csv("data/20200806.csv", encoding='utf8',header=1)

# works[1].drop('Unnamed: 0', axis=1).set_index(['需求ID'])
# dd=works[1].drop('Unnamed: 0',axis=1)
# # 按需求ID聚合
# missions=dd.sort_values(by='需求ID')[['需求ID','需求名称','开发人员']]
# missions['NUM'] = 1

# label = missions[['需求ID','开发人员','NUM','需求名称']]
# grouped = label['NUM'].groupby([label['需求ID'],label['开发人员']])
# statics = dict(grouped.size())

# data = [(key1,key2, statics[(key1,key2)]) for (key1,key2) in statics.keys() ]

# tm = missions[['需求ID','需求名称']]
# req_map = {}
# for i in tm.index:
#     req_map[tm.iloc[i,0]] = tm.iloc[i,1].split("\"")[0] + '...'

works
# Out:
#     序号          创建时间          修改时间  子任务单号  \
# 0    1  44041.707975  44043.853704   2622
# 1    1  44041.708889  44043.853808   2621
# 2    1  44041.704919  44043.854039   2619
# 3    1  44041.704745  44043.854190   2618
# 4    1  44041.702373  44043.854248   2617
# ..  ..           ...           ...    ...
# 91   1  44041.690289  44049.970012   2593
# 92   1  44041.689699  44049.963889   2592
# 93   1  44041.689028  44049.963889   2591
# 94   1  44041.630382  44049.963889   2567
# 95   1  44041.629479  44049.963889   2566
#
#                                             子任务概述  需求ID               需求名称  \
# 0                  【研发侧发起优化】调整APP网络层框架处理网络超时等页面响应   843      性能优化需求（41-44）
# 1                     【研发侧发起优化】安卓拨号详情点击返回页面卡顿问题优化   843      性能优化需求（41-44）
# 2                     【APP】162、已登录下我的模块未登录过渡页屏蔽显示   839  3、功能优化需求（104-166）
# 3                         【APP】160、我的模块号码区域点击热区调整   839  3、功能优化需求（104-166）
# 4                              【APP】107、底部栏公司名称变更   839  3、功能优化需求（104-166）
# ..                                            ...   ...                ...
# 91               【后台】17、5G快签设置和加V电话设置、允许只设置一种限制周期   742             后台优化需求
# 92  【PC后台】14、消息发送限制配置管理&mdash;默认配置，一旦修改前端就会出现各种异常   742             后台优化需求
# 93                            【PC后台】16、5G快签黑白名单设置   844           后台优化需求16
# 94                         【PC后台】不允许任意文件上传，需要标注类型   828      超级号管理后台渗透测试风险
# 95                   【PC后台】运营管理后台敏感信息明文传输，需要加密或脱敏   828      超级号管理后台渗透测试风险
#
#      状态 开发人员  产品经理 测试人员 方案人员  需求工时  优先度  需求版本号  \
# 0   测试中  王创彬   杨少东  范清云  刘庆忠   1.0    1   V1.0
# 1   测试中  王创彬   杨少东  范清云  刘庆忠   1.0    1   V1.0
# 2   测试中  林梓杰    欧龙  范清云  刘庆忠   0.5    1   V1.0
# 3   测试中  林梓杰    欧龙  范清云  刘庆忠   0.5    1   V1.0
# 4   测试中  刘连子   杨少东  范清云  刘庆忠   0.1    1   V1.0
# ..  ...  ...   ...  ...  ...   ...  ...    ...
# 91   终结   莫南   杨少东  侯广榕  龙晓泉   1.0    1  v. 15
# 92   终结   莫南   黄丹丽  侯广榕  龙晓泉   1.0    1  v. 15
# 93   终结   莫南   杨少东  侯广榕  龙晓泉   2.0    1  v. 15
# 94   终结   莫南  温林顺1  范清云  龙晓泉   1.0    1    v.1
# 95   终结   莫南  温林顺1  范清云  龙晓泉   1.0    1    v.1
#
#                                       子任务Confluence地址  是否渗透测试 0:是,1:否  \
# 0   http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               0
# 1   http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               1
# 2   http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               1
# 3   http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               1
# 4   http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               1
# ..                                                ...             ...
# 91  http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               0
# 92  http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               0
# 93  http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               0
# 94  http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               0
# 95  http://cmic.tools.bigcloudsys.cn/wiki/pages/vi...               0
#
#         预计提测时间        上线时间
# 0   2020-07-30  2020-07-31
# 1   2020-07-30  2020-07-31
# 2   2020-07-30  2020-07-31
# 3   2020-07-30  2020-07-31
# 4   2020-07-30  2020-07-31
# ..         ...         ...
# 91  2020-08-03  2020-08-06
# 92  2020-08-03  2020-08-06
# 93  2020-08-03  2020-08-06
# 94  2020-08-03  2020-08-06
# 95  2020-08-03  2020-08-06
#
# [96 rows x 19 columns]

# %%
works.set_index(['需求ID'])
missions=works.sort_values(by='需求ID')[['需求ID','需求名称','开发人员']]

# %%
missions['NUM'] = 1

label = missions[['需求ID','开发人员','NUM','需求名称']]
grouped = label['NUM'].groupby([label['需求ID'],label['开发人员']])
statics = dict(grouped.size())

# %%
statics
# Out:
# {(742, '余广琪'): 2,
#  (742, '徐青云'): 3,
#  (742, '莫南'): 2,
#  (742, '龙晓泉'): 2,
#  (765, '莫南'): 2,
#  (799, '刘连子'): 1,
#  (799, '林梓杰'): 1,
#  (799, '莫南'): 2,
#  (828, '莫南'): 2,
#  (837, '余广琪'): 2,
#  (837, '徐青云'): 1,
#  (838, '余广琪'): 2,
#  (838, '徐青云'): 1,
#  (838, '黄宇鹏'): 1,
#  (839, '余广琪'): 2,
#  (839, '刘连子'): 10,
#  (839, '叶计成'): 5,
#  (839, '吴嘉佳'): 16,
#  (839, '林梓杰'): 7,
#  (839, '王创彬'): 6,
#  (839, '莫南'): 1,
#  (839, '谭作伍'): 6,
#  (842, '刘连子'): 1,
#  (842, '叶计成'): 1,
#  (842, '吴嘉佳'): 1,
#  (842, '林梓杰'): 1,
#  (842, '王创彬'): 3,
#  (842, '谭作伍'): 1,
#  (843, '叶计成'): 1,
#  (843, '吴嘉佳'): 1,
#  (843, '王创彬'): 2,
#  (844, '莫南'): 2,
#  (845, '莫南'): 2,
#  (845, '谭作伍'): 1,
#  (848, '龙晓泉'): 1,
#  (861, '莫南'): 1}
